# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

salaryDf = pd.read_csv('salary.csv')
salaryDf
# Out:
#           salary  exprior  yearsworked  yearsrank  market  degree  otherqual  \
# 0    53000.00000        0            0          0    1.17       1          0
# 1    58000.00000        1            0          0    1.24       1          0
# 2    45500.00000        0            0          0    1.21       1          0
# 3    35782.00000        0            2          1    0.99       1          0
# 4    34731.00000        0            2          2    0.91       1          0
# 5    56000.00000        1            0          0    1.19       1          0
# 6    61008.00000        0            2          2    1.33       1          0
# 7    39986.00000        0            2          0    0.99       1          0
# 8    36308.00000        0            2          1    0.85       1          0
# 9    55000.00000        0            0          0    1.23       1          0
# 10   55227.00000        0            3          3    1.23       1          0
# ...

# %% [markdown]
# # Question 1

# %% [markdown]
# #### a) There where 514 people interviewed, because the dataframe has 514 rows that are captured as responses.
#
# #### The missing value is in row 208 (code is below)

# %%
# we are going to look at the number of people that were interviewed 

# to find the accurate number i will get the sum of male.

missingVal = salaryDf[salaryDf['salary'].isnull()]
print(missingVal)

print('The missing value is in column Salary in index 208')
# Out:
#      salary  exprior  yearsworked  yearsrank  market  degree  otherqual  \
# 208     NaN        0           21         10    0.93       1          0
#
#      position  male  Field  yearsabs
# 208         3     1      4         1
# The missing value is in column Salary in index 208

# %% [markdown]
# #### b) The lowest salary is 29 000 , and the highest salary is 96 156 . (code is below)

# %%
# here we are extracting the salary column so that we can focus on it
salary  = salaryDf['salary']

# we want to delete row 208 so it doesn't interfere with our stats later 
salary = salary.drop(salary.index[[208]])

# in order for us to get the lowest and highest salary we have to sort the salary dataframe (column).
salary = sorted(salary)

# print the lowest and highest salary as integers (without decimal points)

print("The lowest salary as an integer, without decimal points is", str(int(salary[0])))
print("The lowest salary as an integer, without decimal points is", str(int(salary[-1])))
print('\n')
# Out:
# The lowest salary as an integer, without decimal points is 29000
# The lowest salary as an integer, without decimal points is 96156

# %% [markdown]
# #### c) The mean salary is 50 863. I have changed the number into an interger

# %%
# here we will find the mean salary using the numpy fynction mean 
mean = np.mean(salary)
print("The Mean salary as an integer, without decimal points is", str(int(mean)))
print("The Mean salary is", str(mean))
# Out:
# The Mean salary as an integer, without decimal points is 50863
# The Mean salary is 50863.22009783626

# %% [markdown]
# #### d) The Standard deviation of the years worked ais  9. I have converted this number into an interger.

# %%
# We will extract the Years Worked column so that we can get the standard  deviation for the years worked

yearsworked = salaryDf['yearsworked']

# getting the standard  deviation using numpy 

std = np.std(yearsworked)

# Printing it out as an integer (without decimal points)

print("The Standard deviation of the years worked as an integer, without decimal points is ", str(int(std)))
print('\n')

# Printing it out std in its original form

print("The Standard deviation of the years worked is", str(std))
# Out:
# The Standard deviation of the years worked as an integer, without decimal points is  9
#
#
# The Standard deviation of the years worked is 9.435503224576872

# %% [markdown]
# #### e) The median for salary is 50096

# %%
med = np.median(salary)
print(int(med))
print(med)
# Out:
# 50096
# 50096.0

# %% [markdown]
# #### f) The interquartile range for salary is 20345

# %%
import scipy.stats
scipy.stats.iqr(salary)
# Out:
# 20345.0

# %% [markdown]
# #### g) There are 386 men and 128 women  in the dataframe.

# %%
gender = salaryDf['male']

# Here we will try and get the number of males in our dataframe
men = gender[gender == 1] .count()

print("The number of males in the sample is ", str(males))
print('\n')


# Here we are going to get the number of females in the dataframe

women = gender[gender == 0] .count()

print("The number of males in the sample is ", str(females))

# we will combine both females and males to plot our graph. 
df  = men, women

labels = ['Males', 'Females', ]
color = ['palegreen','crimson']

plt.pie(df, labels =labels, colors = color, autopct='%1.0f%%')
plt.title('Number of females and males in the sample')
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.show()
# Out:
# The number of males in the sample is  386
#
#
# The number of males in the sample is  128

# %% [markdown]
# #### h) There are  19  women who are executives

# %%
# this dataframe shows us the rows that relate to females
females = salaryDf[salaryDf.male == 0]

# now we need to see how many women are Executives

Executives = females.groupby('position') .size() 
Executives

print("There are ", str(Executives[3]), " women who are executives" )
# Out:
# There are  19  women who are executives

# %% [markdown]
# #### i & j ) It seem that a lot of people earn 0 - 20 000. a few people earn 90 000.

# %%
# Here we will figure out how our different salary groups

salary = salaryDf.groupby('salary') .size() .reset_index(name = 'frq')

df = salary['salary'], salary['frq']


plt.hist(df)
plt.xlabel('Salaries')
plt.ylabel('Number of responses')
plt.title('Salaries of people')
plt.show()

# %% [markdown]
# #### k) According to the graph males earn more than females do.

# %%
# like we did with females, we are trying to get all the rows that relate to males
males = salaryDf[salaryDf.male == 1]

# here we will extract the salary column from both the female and male dataframe

males = males['salary']

# Here we are getting the different salary group.

maleSalary = np.mean(males)
femaleSalary = np.mean(females)

# plotting the graph
height = maleSalary, femaleSalary 
labels = ['Males', 'Females']

plt.bar(labels,height)
plt.ylabel('')
plt.xlabel("")
plt.title('')
plt.show()

# Here we will plot the error bars

# %% [markdown]
# #### l)

# %%
# here we will extract the years worked column from our salaryDf 

yearsworked = salaryDf.groupby('yearsworked') .size()
salary = salaryDf.groupby('salary') .size()

# plotting a graph

# %% [markdown]
# #### m)
